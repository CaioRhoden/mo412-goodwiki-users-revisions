# %% [markdown]
# # Data Exploration Dataset
#
# The goal of this notebooks is to understand the structure and characteristics of the dataset.

# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df_pd = pd.read_parquet("../revisions_no_bots.parquet")
df = pl.from_pandas(df_pd)
df
# Out:
# shape: (605_685, 11)
# ┌────────────┬────────────┬───────┬────────────┬───┬────────────┬───────────┬──────────┬───────────┐
# │ revid      ┆ parentid   ┆ minor ┆ user       ┆ … ┆ slots      ┆ tags      ┆ pageid   ┆ title     │
# │ ---        ┆ ---        ┆ ---   ┆ ---        ┆   ┆ ---        ┆ ---       ┆ ---      ┆ ---       │
# │ i64        ┆ i64        ┆ bool  ┆ str        ┆   ┆ struct[1]  ┆ list[str] ┆ i64      ┆ str       │
# ╞════════════╪════════════╪═══════╪════════════╪═══╪════════════╪═══════════╪══════════╪═══════════╡
# │ 1163683705 ┆ 1073278143 ┆ false ┆ Smasongarr ┆ … ┆ {{"wikitex ┆ ["AWB"]   ┆ 57185536 ┆ Georgia   │
# │            ┆            ┆       ┆ ison       ┆   ┆ t",14787}} ┆           ┆          ┆ Hopley    │
# │ 1170257280 ┆ 1169998062 ┆ true  ┆ Smasongarr ┆ … ┆ {{"wikitex ┆ []        ┆ 15394015 ┆ Willis    │
# │            ┆            ┆       ┆ ison       ┆   ┆ t",39439}} ┆           ┆          ┆ Ward      │
# │ 1162127828 ┆ 1160202917 ┆ true  ┆ Minorax    ┆ … ┆ {{"wikitex ┆ ["wikiedi ┆ 15394015 ┆ Willis    │
# │            ┆            ┆       ┆            ┆   ┆ t",39390}} ┆ tor"]     ┆          ┆ Ward      │
# │ 1160202917 ┆ 1160202005 ┆ false ┆ SheridanFo ┆ … ┆ {{"wikitex ┆ ["visuale ┆ 15394015 ┆ Willis    │
# │            ┆            ┆       ┆ rd         ┆   ┆ t",39421}} ┆ ditor"]   ┆          ┆ Ward      │
# │ 1160202005 ┆ 1152748211 ┆ false ┆ SheridanFo ┆ … ┆ {{"wikitex ┆ ["visuale ┆ 15394015 ┆ Willis    │
# │            ┆            ┆       ┆ rd         ┆   ┆ t",38839}} ┆ ditor"]   ┆          ┆ Ward      │
# │ …          ┆ …          ┆ …     ┆ …          ┆ … ┆ …          ┆ …         ┆ …        ┆ …         │
# │ 1135099269 ┆ 1120571467 ┆ true  ┆ Gaius      ┆ … ┆ {{"wikitex ┆ ["AWB"]   ┆ 62440986 ┆ 44 Union  │
# │            ┆            ┆       ┆ Cornelius  ┆   ┆ t",45682}} ┆           ┆          ┆ Square    │
# │ 1162413149 ┆ 1161172203 ┆ false ┆ ForsythiaJ ┆ … ┆ {{"wikitex ┆ ["wikiedi ┆ 47872332 ┆ The       │
# │            ┆            ┆       ┆ o          ┆   ┆ t",12490}} ┆ tor"]     ┆          ┆ Pioneer   │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Mother    │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Memorial  │
# │ 1161172203 ┆ 1161172179 ┆ false ┆ Another    ┆ … ┆ {{"wikitex ┆ ["visuale ┆ 47872332 ┆ The       │
# │            ┆            ┆       ┆ Believer   ┆   ┆ t",12483}} ┆ ditor"]   ┆          ┆ Pioneer   │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Mother    │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Memorial  │
# │ 1161172179 ┆ 1157785408 ┆ false ┆ Another    ┆ … ┆ {{"wikitex ┆ ["wikiedi ┆ 47872332 ┆ The       │
# │            ┆            ┆       ┆ Believer   ┆   ┆ t",12473}} ┆ tor"]     ┆          ┆ Pioneer   │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Mother    │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Memorial  │
# │ 1157785408 ┆ 1147288183 ┆ false ┆ Another    ┆ … ┆ {{"wikitex ┆ []        ┆ 47872332 ┆ The       │
# │            ┆            ┆       ┆ Believer   ┆   ┆ t",12481}} ┆           ┆          ┆ Pioneer   │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Mother    │
# │            ┆            ┆       ┆            ┆   ┆            ┆           ┆          ┆ Memorial  │
# └────────────┴────────────┴───────┴────────────┴───┴────────────┴───────────┴──────────┴───────────┘

# %% [markdown]
# ## Create Graph - Reviewers+ Pages
#
# L = 233650
# N = 43113 + 36048

# %%
graph_rev_pag = (
    df
    .select(["userid", "pageid"])
    .unique()
)
graph_rev_pag
# Out:
# shape: (233_650, 2)
# ┌─────────────┬──────────┐
# │ userid      ┆ pageid   │
# │ ---         ┆ ---      │
# │ f64         ┆ i64      │
# ╞═════════════╪══════════╡
# │ 1.433803e6  ┆ 5717195  │
# │ 4.3330104e7 ┆ 1678965  │
# │ 3.2904124e7 ┆ 48936686 │
# │ 3.8621216e7 ┆ 57518752 │
# │ 262716.0    ┆ 1234348  │
# │ …           ┆ …        │
# │ 3.1439127e7 ┆ 146947   │
# │ 1.0248457e7 ┆ 1247086  │
# │ 4.5997801e7 ┆ 46991545 │
# │ 4.071608e6  ┆ 373154   │
# │ 4.0581419e7 ┆ 2819577  │
# └─────────────┴──────────┘

# %%
graph_rev_pag.select("userid").unique().count()
# Out:
# shape: (1, 1)
# ┌────────┐
# │ userid │
# │ ---    │
# │ u32    │
# ╞════════╡
# │ 43113  │
# └────────┘

# %%
graph_rev_pag.select("pageid").unique().count()
# Out:
# shape: (1, 1)
# ┌────────┐
# │ pageid │
# │ ---    │
# │ u32    │
# ╞════════╡
# │ 36048  │
# └────────┘

# %% [markdown]
# ## Projeção Users

# %%
clone_graph = graph_rev_pag.clone().rename({"userid": "userid_2"})

## Create a df with users conneting to users via pages and the total of pages shared
graph_users = (
    graph_rev_pag
    .join(clone_graph, left_on="pageid", right_on="pageid", how="inner")
    .filter(pl.col("userid") != pl.col("userid_2"))
    .group_by(["userid", "userid_2"])
    .agg(pl.count("pageid").alias("weight"))
    .rename({"userid": "from", "userid_2": "to"})
)
graph_users
# Out:
# shape: (4_184_680, 3)
# ┌─────────────┬─────────────┬────────┐
# │ from        ┆ to          ┆ weight │
# │ ---         ┆ ---         ┆ ---    │
# │ f64         ┆ f64         ┆ u32    │
# ╞═════════════╪═════════════╪════════╡
# │ 1.8916437e7 ┆ 2.8723648e7 ┆ 1      │
# │ 6.27233e6   ┆ 2.5524306e7 ┆ 1      │
# │ 4.5338532e7 ┆ 4.061563e7  ┆ 1      │
# │ 3.2395809e7 ┆ 4.5824205e7 ┆ 1      │
# │ 1.3037406e7 ┆ 3.9606237e7 ┆ 1      │
# │ …           ┆ …           ┆ …      │
# │ 4.3681007e7 ┆ 36389.0     ┆ 1      │
# │ 4.4372971e7 ┆ 4.6479835e7 ┆ 1      │
# │ 3.8954948e7 ┆ 2.1878292e7 ┆ 1      │
# │ 4.5782117e7 ┆ 3.9450321e7 ┆ 1      │
# │ 4.1780087e7 ┆ 1.073486e6  ┆ 1      │
# └─────────────┴─────────────┴────────┘

# %%
## calculate the the number of users (nodes) and the number of connections (edges)
L = graph_users.shape[0]
N = graph_users.select("from").unique().shape[0]
L, N
# Out:
# (4184680, 42679)

# %%
## degree neighboors
_from = (
    graph_users
    .group_by("from")
    .count()
    .sort("count", descending=True)
)


sns.lineplot(data=_from.to_pandas(), y=range(_from.shape[0]), x="count")
# Out:
# /tmp/ipykernel_27361/4161581555.py:5: DeprecationWarning: `GroupBy.count` was renamed; use `GroupBy.len` instead
#   .count()
# <Axes: xlabel='count'>

# %%
## mean k
_from.select("count").mean()
# Out:
# shape: (1, 1)
# ┌───────┐
# │ count │
# │ ---   │
# │ f64   │
# ╞═══════╡
# │ 32.0  │
# └───────┘
